# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Nguyen Trong**
#
# Data Scientist

# %% [markdown]
# *I love data science because it can help me to answer my own questions.*

# %% [markdown]
# ### Make an addition

# %%
7+5
# Out:
# 12

# %% [markdown]
# * I want to:
# 1. Be a data scientist
# 2. Change the way doctors work in the world
# 3. Change the treatment procedure for patients around the world
# * [My porfolio](drmichael.me)
